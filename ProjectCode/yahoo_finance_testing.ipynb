# %%
import pandas as pd
import yahoo_fin.stock_info as si

tickers=['AMZN','GOOG','PG','KO','IBM','MSFT']

# %%
data=si.get_stats(tickers[0])
data
# Out:
#                                          Attribute         Value
# 0                                Beta (5Y Monthly)          1.12
# 1                                 52-Week Change 3        55.48%
# 2                          S&P500 52-Week Change 3        49.51%
# 3                                   52 Week High 3       3552.25
# 4                                    52 Week Low 3       2038.00
# 5                          50-Day Moving Average 3       3112.28
# 6                         200-Day Moving Average 3       3180.94
# 7                              Avg Vol (3 month) 3         3.59M
# 8                               Avg Vol (10 day) 3         3.22M
# 9                             Shares Outstanding 5          503M
# 10                    Implied Shares Outstanding 6           NaN
# 11                                           Float       429.63M
# 12                            % Held by Insiders 1        14.13%
# ...

# %%
extra_ratio=si.get_stats_valuation(tickers[2])
extra_ratio
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-97e5f7d028cb> in <module>
# ----> 1 extra_ratio=si.get_stats_valuation(tickers[2])
#       2 extra_ratio
#
# ~\anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_stats_valuation(ticker)
#     360
#     361
# --> 362     table = tables[0].reset_index(drop = True)
#     363
#     364     return table
#
# IndexError: list index out of range

# %%
# Out:
# 255.85000610351562

# %%
round(si.get_live_price(tickers[5]),2)
# Out:
# 255.85
