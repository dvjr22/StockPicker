# %%
import pandas as pd
import yahoo_fin.stock_info as si

# %%
evaluationDF = pd.read_csv('../ProjectDatasets/final_recommendations.csv', sep=',', index_col='ticker')

# %%
evaluationDF.head(50)
# Out:
#                                Security SEC filings             GICS Sector  \
# ticker
# PHM                          PulteGroup     reports  Consumer Discretionary
# CNC                 Centene Corporation     reports             Health Care
# DHI                        D. R. Horton     reports  Consumer Discretionary
# PGR                   Progressive Corp.     reports              Financials
# ATO                        Atmos Energy     reports               Utilities
# EXPD                         Expeditors     reports             Industrials
# PKI                         PerkinElmer     reports             Health Care
# TER                            Teradyne     reports  Information Technology
# DGX                   Quest Diagnostics     reports             Health Care
# PG                     Procter & Gamble     reports        Consumer Staples
# AMAT             Applied Materials Inc.     reports  Information Technology
# ...
